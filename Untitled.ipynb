# %% [markdown]
# # 1.loading and inspecting the data

# %%
import numpy as np
import pandas as pd

# %%
audible = pd.read_csv('audible_uncleaned.csv')

# %%
audible.nunique()
# Out:
# name           82767
# author         48374
# narrator       29717
# time            2284
# releasedate     5058
# language          36
# stars            665
# price           1011
# dtype: int64

# %%
df2 = pd.read_csv('audible_cleaned.csv')
df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\2197986914.py in <module>
# ----> 1 df2 = pd.read_csv('audible_cleaned.csv')
#       2 df2
#
# D:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df3 = pd.read_csv('audible_cleaned99.csv')

# %%
df3
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator  time releasedate language  stars  price  ratings
# 0          BillLobely   140  2008-04-08  English    5.0  468.0     34.0
# ...

# %% [markdown]
# ## 1.1 Veiw the first rows of te dataframe

# %%
audible
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %% [markdown]
# ## 1.2 Inspect the columns data Type

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %% [markdown]
# # 2. Clean Text data in Author and Narrator columns

# %% [markdown]
# ## 2.1 Remove writternby from author column

# %%
audible['author'] = audible['author'].str.replace('Writtenby:', '')

# %% [markdown]
# ## 2.2 Remove Narratedby from narrator column

# %%
audible['narrator'] = audible['narrator'].str.replace('Narratedby:', '')

# %% [markdown]
# ## 2.3 Check the results

# %%
audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# ...

# %%
audible['author'] = audible['author'].str.replace('Writtenby:', '')

audible['narrator'] = audible['narrator'].str.replace('Narratedby:', '')

audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# ...

# %% [markdown]
# # 3. Extract Number of stars and ratings from stars column

# %% [markdown]
# # 3.1 Get a glimpse of te stars column

# %%
audible.stars.sample(10)
# Out:
# 60049                  Not rated yet
# 68913                  Not rated yet
# 58795      5 out of 5 stars5 ratings
# 41210      5 out of 5 stars2 ratings
# 32568                  Not rated yet
# 71935    4.5 out of 5 stars2 ratings
# 2265       3 out of 5 stars3 ratings
# 37380                  Not rated yet
# 13153                  Not rated yet
# 27292    5 out of 5 stars101 ratings
# Name: stars, dtype: object

# %% [markdown]
# ## 3.2 Explore the value of star column that are not rated yet

# %%
audible[audible.stars !='Not rated yet' ].stars.sample(10)
# Out:
# 22630         4 out of 5 stars1 rating
# 49806    4.5 out of 5 stars134 ratings
# 38857        4 out of 5 stars2 ratings
# 13821      4.5 out of 5 stars2 ratings
# 79632      4.5 out of 5 stars9 ratings
# 31161         5 out of 5 stars1 rating
# 52970         5 out of 5 stars1 rating
# 42473         3 out of 5 stars1 rating
# 36820         4 out of 5 stars1 rating
# 70462         5 out of 5 stars1 rating
# Name: stars, dtype: object

# %% [markdown]
# ## 3.3 Remove Not rated yet with nan

# %%
audible.stars.replace('Not rated yet',np.nan,inplace = True)
audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator                time releasedate language  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English
# ...

# %% [markdown]
# ## 3.4 Extract the number of stars into the rating_stars and turned into float

# %%
  audible['rating_stars'] = audible['stars'].str.extract('^([\d.]+)').astype(float)

# %%
 audible['stars'].str.extract('^([\d.]+)').astype(float)
# Out:
#          0
# 0      5.0
# 1      4.5
# 2      4.5
# 3      4.5
# 4      4.5
# ...    ...
# 87484  NaN
# 87485  NaN
# 87486  NaN
# 87487  NaN
# 87488  NaN
#
# [87489 rows x 1 columns]

# %% [markdown]
# ## 3.5 Extract the number of rating into the n_ratings and turned into float

# %%
  audible['n_ratings'] = audible['stars'].str.replace('','').str.extract('(\d+) rating').astype(float)

# %%
audible['stars'].str.replace(',','').str.extract('(\d+) rating').astype(float)
# Out:
#            0
# 0       34.0
# 1       41.0
# 2       38.0
# 3       12.0
# 4      181.0
# ...      ...
# 87484    NaN
# 87485    NaN
# 87486    NaN
# 87487    NaN
# 87488    NaN
#
# [87489 rows x 1 columns]

# %% [markdown]
# ## 3.6 Show the results

# %%
audible[['rating_stars','n_ratings']]
# Out:
#        rating_stars  n_ratings
# 0               5.0       34.0
# 1               4.5       41.0
# 2               4.5       38.0
# 3               4.5       12.0
# 4               4.5      181.0
# ...             ...        ...
# 87484           NaN        NaN
# 87485           NaN        NaN
# 87486           NaN        NaN
# 87487           NaN        NaN
# 87488           NaN        NaN
#
# [87489 rows x 2 columns]

# %% [markdown]
# ## 3.7 Drop the stars columns

# %%
audible.drop(columns = ['stars'],axis = 1, inplace = True  )
audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator                time releasedate language   price  \
# 0          BillLobely   2 hrs and 20 mins    04-08-08  English  468.00
# ...

# %% [markdown]
# # 4. change data types

# %% [markdown]
# ## 4.1 Explore the price column

# %%
audible.price.sample(n=10)
# Out:
# 729      189.00
# 49868    683.00
# 56956    497.00
# 56056    586.00
# 36024    683.00
# 75081    668.00
# 55227    836.00
# 7458     164.00
# 56241    703.00
# 51647    586.00
# Name: price, dtype: object

# %% [markdown]
# ## 4.2 Replace the comma with '  '

# %%
audible['price'] = audible.price.str.replace(',','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\3759280233.py in <module>
# ----> 1 audible['price'] = audible.price.str.replace(',','')
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# D:\anaconda\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %% [markdown]
# ## 4.3 Replace 'Free' with 0

# %%
audible['price'] = audible.price.str.replace('Free','0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\4252068375.py in <module>
# ----> 1 audible['price'] = audible.price.str.replace('Free','0')
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# D:\anaconda\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ...

# %% [markdown]
# ## 4.4 Turn price to float

# %%
audible['price'] = audible.price.astype(float)

# %%
audible.price.replace(',','').astype(float)
# Out:
# 0        468.0
# 1        820.0
# 2        410.0
# 3        615.0
# 4        820.0
#          ...
# 87484    596.0
# 87485    820.0
# 87486    938.0
# 87487    680.0
# 87488    569.0
# Name: price, Length: 87489, dtype: float64

# %% [markdown]
# ## 4.5 look at the unique values in ratings_stars column

# %%
audible.rating_stars.unique()
# Out:
# D:\anaconda\lib\site-packages\IPython\lib\pretty.py:700: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   output = repr(obj)
# [5.0, 4.5, 4.0, NaN, 3.5, 3.0, 1.0, 2.0, 2.5, 1.5]
# Categories (9, float64): [1.0, 1.5, 2.0, 2.5, ..., 3.5, 4.0, 4.5, 5.0]

# %% [markdown]
# ## 4.6 Turn rating_stars to category

# %%
audible['rating_stars'] = audible.rating_stars.astype('category')

# %% [markdown]
# ## 4.7 Convert releasedate to_datetime

# %%
audible['releasedate'] = pd.to_datetime(audible.releasedate)

# %% [markdown]
# ## 4.8 Inspect the dataframe

# %%
audible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          87489 non-null  object
#  1   author        87489 non-null  object
#  2   narrator      87489 non-null  object
#  3   time          87489 non-null  object
#  4   releasedate   87489 non-null  datetime64[ns]
#  5   language      87489 non-null  object
#  6   price         87489 non-null  float64
#  7   rating_stars  15072 non-null  category
#  8   n_ratings     15072 non-null  float64
# dtypes: category(1), datetime64[ns](1), float64(2), object(5)
# memory usage: 5.4+ MB

# %% [markdown]
# # 5. Extract hours and minute from the time column

# %% [markdown]
# ## 5.1 Explore the values in the time column

# %%
audible.time.sample(n=10)
# Out:
# 7517       1 hr and 25 mins
# 66618     6 hrs and 19 mins
# 65127      8 hrs and 6 mins
# 18731     6 hrs and 55 mins
# 70139    19 hrs and 35 mins
# 72598     5 hrs and 12 mins
# 34388      1 hr and 15 mins
# 13586     2 hrs and 40 mins
# 52744     9 hrs and 20 mins
# 79473               40 mins
# Name: time, dtype: object

# %% [markdown]
# ## 5.2 Search the entries in the time column for different spellings of min
# Lit try min minutes

# %%
audible.time[audible.time.str.contains('1 min')].sample(n=10)
# Out:
# 59134     3 hrs and 11 mins
# 80001     6 hrs and 11 mins
# 26088     6 hrs and 41 mins
# 87115               31 mins
# 74797     6 hrs and 11 mins
# 56750        1 hr and 1 min
# 55244     6 hrs and 41 mins
# 80409    14 hrs and 41 mins
# 72797     5 hrs and 11 mins
# 14511    12 hrs and 41 mins
# Name: time, dtype: object

# %%
audible.time[audible.time.str.contains('minute')].sample(n=10)
# Out:
# 87180    Less than 1 minute
# 10897    Less than 1 minute
# 87162    Less than 1 minute
# 87100    Less than 1 minute
# 1409     Less than 1 minute
# 9089     Less than 1 minute
# 10898    Less than 1 minute
# 39002    Less than 1 minute
# 87170    Less than 1 minute
# 87192    Less than 1 minute
# Name: time, dtype: object

# %% [markdown]
# ## 5.3 repace hrs, mins, less than 1 minute

# %%
audible['time'] = audible.time.str.replace('hrs','hr')
audible['time'] = audible.time.str.replace('mins','min')

audible['time'] = audible.time.str.replace('Less than 1 minute','1 min')

# %%
audible[['time']]
# Out:
#                    time
# 0       2 hr and 20 min
# 1       13 hr and 8 min
# 2        2 hr and 3 min
# 3      11 hr and 16 min
# 4                 10 hr
# ...                 ...
# 87484   7 hr and 34 min
# 87485   10 hr and 7 min
# 87486   19 hr and 4 min
# 87487    4 hr and 8 min
# 87488    6 hr and 1 min
#
# [87489 rows x 1 columns]

# %% [markdown]
# ## 5.4 Extract the number of hours,minutes turn into integer then combine hours and minutes into the time_mins column

# %%
hours = audible['time'].str.extract('(\d+) hr').fillna(0).astype(int)
                                    
                                    
mins = audible['time'].str.extract('(\d+) min').fillna(0).astype(int)
                                    
audible[['time_mins']] = hours * 60 + mins
                                   
audible[['time_mins']]
# Out:
#        time_mins
# 0            140
# 1            788
# 2            123
# 3            676
# 4            600
# ...          ...
# 87484        454
# 87485        607
# 87486       1144
# 87487        248
# 87488        361
#
# [87489 rows x 1 columns]

# %% [markdown]
# ## 5.5 Check the dataframe

# %%
audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator              time releasedate language  price  \
# 0          BillLobely   2 hr and 20 min  2008-04-08  English  468.0
# ...

# %% [markdown]
# ## 5.6 Drop time column

# %%
audible.drop(columns=['time'],axis=1, inplace=True)

# %%
audible
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator releasedate language  price rating_stars  n_ratings  \
# 0          BillLobely  2008-04-08  English  468.0          5.0       34.0
# ...

# %% [markdown]
# # 6. Check data ranges

# %% [markdown]
# ## 6.1 plot histogram of all the numerical column

# %%
audible.hist(figsize=(10,10), bins = 100)
pl
# Out:
# array([[<AxesSubplot:title={'center':'releasedate'}>,
#         <AxesSubplot:title={'center':'price'}>],
#        [<AxesSubplot:title={'center':'n_ratings'}>,
#         <AxesSubplot:title={'center':'time_mins'}>]], dtype=object)

# %% [markdown]
# ## 6.2 look at the numeric columns

# %%
audible.describe()
# Out:
#               price     n_ratings     time_mins
# count  87489.000000  15072.000000  87489.000000
# mean     559.009246     15.509156    417.497663
# std      336.096642     61.975221    364.559399
# min        0.000000      1.000000      1.000000
# 25%      268.000000      1.000000    142.000000
# 50%      585.000000      2.000000    386.000000
# 75%      755.000000      7.000000    584.000000
# max     7198.000000    985.000000   8595.000000

# %% [markdown]
# ## 6.3 lank at the numeric columns

# %%
audible.describe(exclude=[np.number])
# Out:
# C:\Users\ahmad bsis\AppData\Local\Temp\ipykernel_17348\443772610.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   audible.describe(exclude=[np.number])
#                   name    author   narrator          releasedate language  \
# count            87489     87489      87489                87489    87489
# unique           82767     48374      29717                 5058       36
# top     The Art of War  矢島雅弘,石橋遊  anonymous  2018-05-16 00:00:00  English
# freq                20       874       1034                  773    61884
# first              NaN       NaN        NaN  1998-12-27 00:00:00      NaN
# last               NaN       NaN        NaN  2025-11-14 00:00:00      NaN
#
#         rating_stars
# count        15072.0
# unique           9.0
# top              5.0
# ...

# %% [markdown]
# ## 6.4 Transform prices to USD (*0.012)

# %%
audible['price'] = audible.price * 0.012
audible.price.describe()
# Out:
# count    87489.000000
# mean         0.080497
# std          0.048398
# min          0.000000
# 25%          0.038592
# 50%          0.084240
# 75%          0.108720
# max          1.036512
# Name: price, dtype: float64

# %% [markdown]
# ## 6.5 inspect the languge column befor

# %%
audible.head()
# Out:
#                                          name           author  \
# 0                  Geronimo Stilton #11 & #12  GeronimoStilton
# 1                            The Burning Maze      RickRiordan
# 2                                The Deep End       JeffKinney
# 3                        Daughter of the Deep      RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      RickRiordan
#
#          narrator releasedate language  price rating_stars  n_ratings  \
# 0      BillLobely  2008-04-08  English  5.616          5.0       34.0
# 1   RobbieDaymond  2018-01-05  English  9.840          4.5       41.0
# 2      DanRussell  2020-06-11  English  4.920          4.5       38.0
# 3  SoneelaNankani  2021-05-10  English  7.380          4.5       12.0
# 4  JesseBernstein  2010-01-13  English  9.840          4.5      181.0
#
#    time_mins
# 0        140
# 1        788
# 2        123
# 3        676
# 4        600

# %% [markdown]
# ## 6.6 update capitalizationj in language column

# %%
audible['language'] = audible.language.str.capitalize()

audible.language.unique()
# Out:
# array(['English', 'Hindi', 'Spanish', 'German', 'French', 'Catalan',
#        'Swedish', 'Italian', 'Danish', 'Finnish', 'Dutch', 'Hebrew',
#        'Russian', 'Polish', 'Galician', 'Afrikaans', 'Icelandic',
#        'Romanian', 'Japanese', 'Tamil', 'Portuguese', 'Urdu', 'Hungarian',
#        'Czech', 'Bulgarian', 'Mandarin_chinese', 'Basque', 'Korean',
#        'Arabic', 'Greek', 'Turkish', 'Ukrainian', 'Slovene', 'Norwegian',
#        'Telugu', 'Lithuanian'], dtype=object)

# %% [markdown]
# # 7. Check for duplicates

# %% [markdown]
# ## 7.1 Check for null values

# %%
audible.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 7.2 Create a list of subset  columns and assagin to substet_col

# %%
subset_col = [ 'name','author','narrator','time_mins','price']
audible.duplicated(subset=subset_col).sum()
# Out:
# 70

# %% [markdown]
# ## 7.3 Drop duplicates rows keeping the last release data

# %%
audible[audible.duplicated(subset=subset_col, keep=False)].sort_values(by='name')
# Out:
#                                               name                    author  \
# 63978      "Das Böse ist des Menschen beste Kraft"         ChristianLiederer
# 63965      "Das Böse ist des Menschen beste Kraft"         ChristianLiederer
# 24625                         90 Minutes in Heaven     DonPiper,CecilMurphey
# 24116                         90 Minutes in Heaven     DonPiper,CecilMurphey
# 16971                                 Adagio in Dm                 BillBrown
# ...                                            ...                       ...
# 18338  What I Talk About When I Talk About Running            HarukiMurakami
# 38021                   When Women Ruled the World                KaraCooney
# 20260                   When Women Ruled the World                KaraCooney
# 22158                                Wings of Fire  APJAbdulKalam,ArunTiwari
# 64428                                Wings of Fire  APJAbdulKalam,ArunTiwari
#
# ...

# %%
audible.drop_duplicates(subset=subset_col,keep='last', inplace = True)

# %% [markdown]
# ## 7.4 check again foe duplicates uisng our subset of columns

# %%
audible.duplicated(subset=subset_col).sum()
# Out:
# 0

# %% [markdown]
# # 8. Dealing with missing data

# %% [markdown]
# ## 8.1 Check for null values

# %%
audible.isna().sum()
# Out:
# name                0
# author              0
# narrator            0
# releasedate         0
# language            0
# price               0
# rating_stars    72387
# n_ratings       72387
# time_mins           0
# dtype: int64
